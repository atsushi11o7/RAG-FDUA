# %%
import os
import sys
from pathlib import Path

repo_dir = Path.cwd().parents[0]
if repo_dir.as_posix() not in sys.path:
    sys.path.append(repo_dir.as_posix())

# %% [markdown]
# # load pdf test

# %%
from src.store import load_pdfs, load_pdfs_use_pypdfium2

# %%
def load_pdfs_test(pdfs_path):
    input_path = pdfs_path

    pdf_file_paths = [
        os.path.join(input_path, f)
        for f in os.listdir(input_path)
        if f.endswith(".pdf")
    ]

    pdf_data_list = load_pdfs_use_pypdfium2(pdf_file_paths)

    for item in pdf_data_list:
        print("====== ファイル名:", item["file_name"], "======")
        print("[1ページ目の情報]")
        print("  page_number:", item["first_page"].metadata["page_number"])
        print("  content:", item["first_page"].page_content)
        
        print("[2ページ目以降]")
        for doc in item["other_pages"]:
            print("  page_number:", doc.metadata["page_number"])
            print("  content:", doc.page_content)
        
    return pdf_data_list

# %%
load_pdfs_test(repo_dir.joinpath("data", "documents"))

# %% [markdown]
# # Preprocessing

# %%
from src.store import format_texts_with_gpt4o

# %%
pdfs_path = repo_dir.joinpath("data", "documents")

pdf_file_paths = [
    os.path.join(pdfs_path, f)
    for f in os.listdir(pdfs_path)
    if f.endswith(".pdf")
]

pdf_data_list = load_pdfs_use_pypdfium2(pdf_file_paths)

format_texts_with_gpt4o(pdf_data_list, output_dir=repo_dir.joinpath("data", "formatted_texts"))
# Out:
# /home/atsushi/repositories/RAG-FDUA/venv/lib/python3.10/site-packages/pypdfium2/_helpers/textpage.py:80: UserWarning: get_text_range() call with default params will be implicitly redirected to get_text_bounded()
#   warnings.warn("get_text_range() call with default params will be implicitly redirected to get_text_bounded()")
# /home/atsushi/repositories/RAG-FDUA/src/store/preprocessing.py:60: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   formatting_chain = LLMChain(
# /home/atsushi/repositories/RAG-FDUA/src/store/preprocessing.py:77: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response_str = formatting_chain.run({"text": input_text})
# [INFO] Formatted: 8 -> /home/atsushi/repositories/RAG-FDUA/data/formatted_texts/8_formatted.txt
# ...

# %% [markdown]
# # FAQ

# %%
from src.store import summarize_formatted_texts_with_gpt4o

# %%
summarize_formatted_texts_with_gpt4o(repo_dir.joinpath("data", "formatted_texts"), repo_dir.joinpath("data", "summarized_texts"))
# Out:
# []
# [INFO] ファイル '8_formatted' のページ 1 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 2 の要約が空です
# [{'question': 'サントリーコーポレーションの経営理念は何ですか？', 'answer': 'サントリーグループ企業理念は「人と自然と響きあい、豊かな生活文化を創造し、『人間ち）の輝き』をめざす。」です。この理念のもと、すべての従業員が大切にすべき価値観として「Growing for Good」「やってみなは」「利益三分主義」の3つを定めています。'}]
# []
# [INFO] ファイル '8_formatted' のページ 4 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 5 の要約が空です
# [{'question': 'サントリーグループの経営理念は何ですか', 'answer': 'サントリーグループの経営理念は「人と自然と響きあい、豊かな生活文化を創造し、『人間の生命の輝き』をめざす」というものです。'}]
# []
# [INFO] ファイル '8_formatted' のページ 7 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 8 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 9 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 10 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 11 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 12 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 13 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 14 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 15 の要約が空です
# []
# [INFO] ファイル '8_formatted' のページ 16 の要約が空です
# []
# ...

# %% [markdown]
# # Vectorize

# %%
from src.store import vectorize_formatted_texts

# %%
formatted_texts_dir = repo_dir.joinpath("data", "formatted_texts")  # フォーマット済みテキストファイルのディレクトリ
vector_store_dir = repo_dir.joinpath("data", "vectorize_dir", "ver1")        # ベクトルストアの保存先ディレクトリ
collection_name = "pdf_pages_ver1"                # Chromaコレクション名

retriever = vectorize_formatted_texts(
    formatted_texts_dir=str(formatted_texts_dir),
    vector_store_dir=str(vector_store_dir),
    collection_name=str(collection_name)
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 5
#       2 vector_store_dir = repo_dir.joinpath("data", "vectorize_dir", "ver1")        # ベクトルストアの保存先ディレクトリ
#       3 collection_name = "pdf_pages_ver1"                # Chromaコレクション名
# ----> 5 retriever = vectorize_formatted_texts(
#       6     formatted_texts_dir=str(formatted_texts_dir),
#       7     vector_store_dir=str(vector_store_dir),
#       8     collection_name=str(collection_name)
#       9 )
#
# File ~/repositories/RAG-FDUA/src/store/vectorize.py:84, in vectorize_formatted_texts(formatted_texts_dir, vector_store_dir, collection_name)
#      81     raise ValueError("No documents found to vectorize.")
#      83 # ベクトルストアの作成
# ---> 84 vectorstore = Chroma.from_documents(
#      85     documents=documents,
#      86     embedding=embeddings,
#      87     persist_directory=vector_store_dir,
# ...
